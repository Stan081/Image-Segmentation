# %%
# importing os module for environment variables
import os
# importing necessary functions from dotenv library
from dotenv import load_dotenv, dotenv_values 
# loading variables from .env file
load_dotenv()
# Out:
# True

# %%
import requests

def get_google_static_map(api_key, center_lat, center_lng, width, height, zoom, scale=2, maptype="satellite", format="jpg"):
    # Define the base URL for the Google Static Maps API
    base_url = "https://maps.googleapis.com/maps/api/staticmap"

    # Define the parameters for the API request
    params = {
        "center": f"{center_lat},{center_lng}",
        "size": f"{width}x{height}",
        "scale": scale,
        "maptype": maptype,
        "format": format,
        "key": api_key,
        "zoom": zoom
    }

    # Make the API request
    response = requests.get(base_url, params=params)

    # Save the image if the request was successful
    if response.status_code == 200:
        with open("map_image2.jpg","wb") as f:
            f.write(response.content)
        print("Map image saved as map_image.jpg")
    else:
        print("Error:", response.status_code, response.text)

# Example usage
api_key = os.getenv("API")
center_lat = 30.29149645
center_lng = -97.73303421
width = 384
height = 384
zoom = 19
get_google_static_map(api_key, center_lat, center_lng, width, height, zoom)
# Out:
# Map image saved as map_image.jpg

# %%
import math

def calculate_ground_area(center_lat, zoom, width, height):
    # Constants
    equatorial_circumference = 40075016.686  # in meters
    tile_size = 256  # in pixels

    # Calculate ground resolution
    ground_resolution = equatorial_circumference / (2**zoom * tile_size)

    # Correct for latitude
    latitude_correction_factor = math.cos(math.radians(center_lat))
    adjusted_resolution = ground_resolution * latitude_correction_factor

    # Calculate ground area
    ground_width = adjusted_resolution * width
    ground_height = adjusted_resolution * height
    ground_area = ground_width * ground_height

    return ground_area, ground_width, ground_height

# Example usage

area, g_width, g_height = calculate_ground_area(center_lat, zoom, 384, 384)
print(f"Approximate ground area: {area:.2f} square meters, ground width: {g_width:.2f} meters, ground height: {g_height:.2f}  ")
# Out:
# Approximate ground area: 9801.33 square meters, ground width: 99.00 meters, ground height: 99.00

# %%
total_pixel_area = width * height
conversion_factor = area / total_pixel_area

# %%
print(total_pixel_area)
print(conversion_factor)
# Out:
# 147456
# 0.06646952685225954

# %%
import matplotlib.pyplot as plt

# Example training accuracy data for 3 models
epochs = [1, 2, 3, 4, 5]
model_1_accuracy = [0.8778948187828064, 0.9208141565322876, 0.9338930249214172, 0.9390712976455688, 0.9444714188575745]
model_2_accuracy = [0.9188871383666992, 0.9488382935523987, 0.9565479755401611, 0.9621827006340027, 0.966303288936615]
model_3_accuracy = [0.9115585088729858, 0.9543153047561646, 0.9678842425346375, 0.9733502268791199, 0.977645993232727]

# Plotting the training accuracy
plt.figure(figsize=(8, 6))
plt.plot(epochs, model_1_accuracy, label="Model 1", marker='o')
plt.plot(epochs, model_2_accuracy, label="Model 2", marker='s')
plt.plot(epochs, model_3_accuracy, label="Model 3", marker='^')

# Adding labels, title, and legend
plt.xlabel("Epochs")
plt.ylabel("Training Accuracy")
plt.title("Training Accuracy Comparison")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example training accuracy data for 3 models
epochs = [1, 2, 3, 4, 5]
model_1_accuracy = [0.8514876961708069, 0.9075190424919128, 0.9264988899230957, 0.8962502479553223, 0.9378722906112671]
model_2_accuracy = [0.8762228488922119,0.8980786800384521, 0.9098284244537354, 0.9269289374351501, 0.9461907744407654]
model_3_accuracy = [0.9111072421073914, 0.9476809501647949, 0.9572020173072815, 0.9624776244163513, 0.9659955501556396]

# Plotting the training accuracy
plt.figure(figsize=(8, 6))
plt.plot(epochs, model_1_accuracy, label="Model 1", marker='o')
plt.plot(epochs, model_2_accuracy, label="Model 2", marker='s')
plt.plot(epochs, model_3_accuracy, label="Model 3", marker='^')

# Adding labels, title, and legend
plt.xlabel("Epochs")
plt.ylabel("Validation Accuracy")
plt.title("Validation Accuracy Comparison")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example training accuracy data for 3 models
epochs = [1, 2, 3, 4, 5]
model_1_accuracy = [0.298464298248291, 0.20096898078918457, 0.16856306791305542, 0.15575219690799713, 0.14272262156009674] 
model_2_accuracy =  [0.2039889097213745, 0.1314174234867096, 0.11188139021396637, 0.0972006693482399, 0.08629205822944641] 
model_3_accuracy =[0.2179688811302185, 0.11735573410987854, 0.09372372925281525, 0.06772574037313461, 0.05609908699989319] 
# Plotting the training accuracy
plt.figure(figsize=(8, 6))
plt.plot(epochs, model_1_accuracy, label="Model 1", marker='o')
plt.plot(epochs, model_2_accuracy, label="Model 2", marker='s')
plt.plot(epochs, model_3_accuracy, label="Model 3", marker='^')

# Adding labels, title, and legend
plt.xlabel("Epochs")
plt.ylabel("Training Loss")
plt.title("Training Loss Comparison")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example training accuracy data for 3 models
epochs = [1, 2, 3, 4, 5]
model_1_accuracy = [0.3584232032299042, 0.23268277943134308, 0.17957812547683716, 0.22142060101032257, 0.17041848599910736]
model_2_accuracy =  [0.25132691860198975, 0.21133683621883392, 0.19357609748840332, 0.17085345089435577, 0.14312511682510376]
model_3_accuracy = [0.22380393743515015, 0.14201150834560394, 0.11404361575841904, 0.0994451567530632, 0.09588652104139328]
# Plotting the training accuracy
plt.figure(figsize=(8, 6))
plt.plot(epochs, model_1_accuracy, label="Model 1", marker='o')
plt.plot(epochs, model_2_accuracy, label="Model 2", marker='s')
plt.plot(epochs, model_3_accuracy, label="Model 3", marker='^')

# Adding labels, title, and legend
plt.xlabel("Epochs")
plt.ylabel("Validation Loss")
plt.title("Validation Loss Comparison")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example training accuracy data for 3 models
epochs = [1, 2, 3, 4, 5]
training_accuracy = [0.8778948187828064, 0.9208141565322876, 0.9338930249214172, 0.9390712976455688, 0.9444714188575745]
val_accuracy =  [0.8514876961708069, 0.9075190424919128, 0.9264988899230957, 0.8962502479553223, 0.9378722906112671]
# Plotting the training accuracy
plt.figure(figsize=(8, 6))
plt.plot(epochs, training_accuracy, label="Training", marker='o')
plt.plot(epochs, val_accuracy, label="Validation", marker='s')

# Adding labels, title, and legend
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Model1 Training vs Validation Accuracy Comparison")   
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example training accuracy data for 3 models
epochs = [1, 2, 3, 4, 5]
training_loss = [0.298464298248291, 0.20096898078918457, 0.16856306791305542, 0.15575219690799713, 0.14272262156009674]
val_loss =  [0.3584232032299042, 0.23268277943134308, 0.17957812547683716, 0.22142060101032257, 0.17041848599910736]
# Plotting the training accuracy
plt.figure(figsize=(8, 6))
plt.plot(epochs, training_loss, label="Training", marker='o')
plt.plot(epochs, val_loss, label="Validation", marker='s')

# Adding labels, title, and legend
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Model1 Training vs Validation Loss Comparison")   
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example training accuracy data for 3 models
epochs = [1, 2, 3, 4, 5]
training_accuracy = [0.9188871383666992, 0.9488382935523987, 0.9565479755401611, 0.9621827006340027, 0.966303288936615]
val_accuracy =  [0.8762228488922119, 0.8980786800384521, 0.9098284244537354, 0.9269289374351501, 0.9461907744407654]
# Plotting the training accuracy
plt.figure(figsize=(8, 6))
plt.plot(epochs, training_accuracy, label="Training", marker='o')
plt.plot(epochs, val_accuracy, label="Validation", marker='s')

# Adding labels, title, and legend
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Model2 Training vs Validation Accuracy Comparison")   
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example training accuracy data for 3 models
epochs = [1, 2, 3, 4, 5]
training_loss = [0.2039889097213745, 0.1314174234867096, 0.11188139021396637, 0.0972006693482399, 0.08629205822944641] 
val_loss =  [0.25132691860198975, 0.21133683621883392, 0.19357609748840332, 0.17085345089435577, 0.14312511682510376]
# Plotting the training accuracy
plt.figure(figsize=(8, 6))
plt.plot(epochs, training_loss, label="Training", marker='o')
plt.plot(epochs, val_loss, label="Validation", marker='s')

# Adding labels, title, and legend
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Model2 Training vs Validation Loss Comparison")   
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example training accuracy data for 3 models
epochs = [1, 2, 3, 4, 5]
training_accuracy = [0.9115585088729858, 0.9543153047561646, 0.9678842425346375, 0.9733502268791199, 0.977645993232727]
val_accuracy =  [0.9111072421073914, 0.9476809501647949, 0.9572020173072815, 0.9624776244163513, 0.9659955501556396]
# Plotting the training accuracy
plt.figure(figsize=(8, 6))
plt.plot(epochs, training_accuracy, label="Training", marker='o')
plt.plot(epochs, val_accuracy, label="Validation", marker='s')

# Adding labels, title, and legend
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Model3 Training vs Validation Accuracy Comparison")   
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example training loss data for 3 models
epochs = [1, 2, 3, 4, 5]
training_loss = [0.2039889097213745, 0.1314174234867096, 0.11188139021396637, 0.0972006693482399, 0.08629205822944641] 
val_loss = [0.2179688811302185, 0.11735573410987854, 0.09372372925281525, 0.06772574037313461, 0.05609908699989319] 
# Plotting the training Loss
plt.figure(figsize=(8, 6))
plt.plot(epochs, training_loss, label="Training", marker='o')
plt.plot(epochs, val_loss, label="Validation", marker='s')

# Adding labels, title, and legend
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Model3 Training vs Validation Loss Comparison")   
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example IOU scores for 3 models
iou_model_1 = [0.75, 0.78, 0.80, 0.82, 0.85]
iou_model_2 = [0.72, 0.76, 0.79, 0.81, 0.84]
iou_model_3 = [0.70, 0.74, 0.77, 0.80, 0.83]

# Plotting the IOU scores
plt.figure(figsize=(8, 6))
plt.plot(epochs, iou_model_1, label="Model 1", marker='o')
plt.plot(epochs, iou_model_2, label="Model 2", marker='s')
plt.plot(epochs, iou_model_3, label="Model 3", marker='^')

# Adding labels, title, and legend
plt.xlabel("Epochs")
plt.ylabel("IOU Score")
plt.title("IOU Score Comparison")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.image as img

# Create a dummy image of size 5000x5000 for visualization
image_size = (5000, 5000)
image = img.imread("AerialImageDataset/train/gt/austin1.tif")

# Tile size
tile_size = (384, 384)

# Calculate the number of tiles in each dimension
num_tiles_x = image_size[1] // tile_size[1]
num_tiles_y = image_size[0] // tile_size[0]

# Plot the image
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(image, cmap='gray')

# Draw the grid
for i in range(num_tiles_x + 1):
    x = i * tile_size[1]
    ax.axvline(x=x, color='red', linestyle='--', linewidth=0.7)

for j in range(num_tiles_y + 1):
    y = j * tile_size[0]
    ax.axhline(y=y, color='red', linestyle='--', linewidth=0.7)

# Add a rectangle to highlight the first tile
rect = patches.Rectangle((0, 0), tile_size[1], tile_size[0], linewidth=1, edgecolor='blue', facecolor='none')
ax.add_patch(rect)

# Set the title and show the plot
ax.set_title("Tile Splits Visualization")
plt.show()
